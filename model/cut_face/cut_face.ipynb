# %%
from google.colab import drive
drive.mount('/content/drive')

from google.colab.patches import cv2_imshow

from imutils import face_utils
import numpy as np
import argparse
import imutils
import dlib
import cv2
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def print_image_info(image):
    print('이미지 사이즈 : {}'.format(image.shape))
    print('이미지 dtype : {}'.format(image.dtype))
    print('이미지 Height : {}'.format(image.shape[0]))
    print('이미지 Width : {}'.format(image.shape[1]))
    print('이미지 전체 픽셀 개수 : {}'.format(image.size))

# %%
root_dir = '/content/drive/MyDrive/face/winter/soo'

# %%
img_path_list = []
possible_img_extension = ['.jpg', '.jpeg', '.JPG', '.bmp', '.png'] # 이미지 확장자들
 
for (root, dirs, files) in os.walk(root_dir):
    if len(files) > 0:
        for file_name in files:
            if os.path.splitext(file_name)[1] in possible_img_extension:
                img_path = root + '/' + file_name
                
                # 경로에서 \를 모두 /로 바꿔줘야함
                img_path = img_path.replace('\\', '/') # \는 \\로 나타내야함         
                img_path_list.append(img_path)
                             
print(img_path_list)
# Out:
# ['/content/drive/MyDrive/face/winter/soo/00000000.jpg', '/content/drive/MyDrive/face/winter/soo/00000004.jpg', '/content/drive/MyDrive/face/winter/soo/00000005.jpg', '/content/drive/MyDrive/face/winter/soo/00000003.jpg', '/content/drive/MyDrive/face/winter/soo/00000002.jpg', '/content/drive/MyDrive/face/winter/soo/00000001.jpg', '/content/drive/MyDrive/face/winter/soo/00000009.jpg', '/content/drive/MyDrive/face/winter/soo/00000006.jpg', '/content/drive/MyDrive/face/winter/soo/00000007.jpg', '/content/drive/MyDrive/face/winter/soo/00000011.jpg', '/content/drive/MyDrive/face/winter/soo/00000012.jpg', '/content/drive/MyDrive/face/winter/soo/00000010.jpg', '/content/drive/MyDrive/face/winter/soo/00000013.jpg', '/content/drive/MyDrive/face/winter/soo/00000016.jpg', '/content/drive/MyDrive/face/winter/soo/00000014.jpg', '/content/drive/MyDrive/face/winter/soo/00000017.jpg', '/content/drive/MyDrive/face/winter/soo/00000019.jpg', '/content/drive/MyDrive/face/winter/soo/00000020.jpg', '/content/drive/MyDrive/face/winter/soo/00000023.jpg', '/content/drive/MyDrive/face/winter/soo/00000024.jpg', '/content/drive/MyDrive/face/winter/soo/00000025.jpg', '/content/drive/MyDrive/face/winter/soo/00000026.jpg', '/content/drive/MyDrive/face/winter/soo/00000027.jpg', '/content/drive/MyDrive/face/winter/soo/00000029.jpg', '/content/drive/MyDrive/face/winter/soo/00000028.jpg', '/content/drive/MyDrive/face/winter/soo/00000030.jpg', '/content/drive/MyDrive/face/winter/soo/00000031.jpg', '/content/drive/MyDrive/face/winter/soo/00000033.jpg', '/content/drive/MyDrive/face/winter/soo/00000036.jpg', '/content/drive/MyDrive/face/winter/soo/00000039.jpg', '/content/drive/MyDrive/face/winter/soo/00000042.jpg', '/content/drive/MyDrive/face/winter/soo/00000041.jpg', '/content/drive/MyDrive/face/winter/soo/00000044.jpg', '/content/drive/MyDrive/face/winter/soo/00000043.jpg', '/content/drive/MyDrive/face/winter/soo/00000047.jpg', '/content/drive/MyDrive/face/winter/soo/00000049.jpg', '/content/drive/MyDrive/face/winter/soo/00000051.jpg', '/content/drive/MyDrive/face/winter/soo/00000052.jpg', '/content/drive/MyDrive/face/winter/soo/00000054.jpg', '/content/drive/MyDrive/face/winter/soo/00000055.jpg', '/content/drive/MyDrive/face/winter/soo/00000058.jpg', '/content/drive/MyDrive/face/winter/soo/00000062.jpg', '/content/drive/MyDrive/face/winter/soo/00000063.jpg', '/content/drive/MyDrive/face/winter/soo/00000064.jpg', '/content/drive/MyDrive/face/winter/soo/00000065.jpg', '/content/drive/MyDrive/face/winter/soo/00000069.jpg', '/content/drive/MyDrive/face/winter/soo/00000071.jpg', '/content/drive/MyDrive/face/winter/soo/00000074.jpg', '/content/drive/MyDrive/face/winter/soo/00000072.jpg', '/content/drive/MyDrive/face/winter/soo/00000077.jpg', '/content/drive/MyDrive/face/winter/soo/00000076.jpg', '/content/drive/MyDrive/face/winter/soo/00000078.jpg', '/content/drive/MyDrive/face/winter/soo/00000079.jpg', '/content/drive/MyDrive/face/winter/soo/00000080.jpg', '/content/drive/MyDrive/face/winter/soo/00000081.jpg', '/content/drive/MyDrive/face/winter/soo/00000085.jpg', '/content/drive/MyDrive/face/winter/soo/00000084.jpg', '/content/drive/MyDrive/face/winter/soo/00000088.jpg', '/content/drive/MyDrive/face/winter/soo/00000087.jpg', '/content/drive/MyDrive/face/winter/soo/00000091.jpg', '/content/drive/MyDrive/face/winter/soo/00000092.jpg', '/content/drive/MyDrive/face/winter/soo/00000094.jpg', '/content/drive/MyDrive/face/winter/soo/00000095.jpg', '/content/drive/MyDrive/face/winter/soo/00000097.jpg']

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('/content/drive/MyDrive/shape_predictor_68_face_landmarks.dat')

# %%
file_num = 120
for image in img_path_list:
  print(image)
  image = cv2.imread(image)
  
  
  image = imutils.resize(image, width=500)
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  # detect faces in the grayscale image
  rects = detector(gray, 1)

  for (i, rect) in enumerate(rects):
	# determine the facial landmarks for the face region, then
	# convert the facial landmark (x, y)-coordinates to a NumPy
	# array
	  shape = predictor(gray, rect)
	  shape = face_utils.shape_to_np(shape)
	# convert dlib's rectangle to a OpenCV-style bounding box
	# [i.e., (x, y, w, h)], then draw the face bounding box
	  (x, y, w, h) = face_utils.rect_to_bb(rect)
	  #cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
	  face = image[y:(y+h), x:(x+w)].copy()
  resized = imutils.resize(face, width=100)
  print_image_info(resized)

  #cv2_imshow(resized)
  #cv2.imshow("Output", image)
  #cv2.imshow("face", face)
  #cv2.waitKey(0)
  save_file = '/content/drive/MyDrive/only_cut_face/dataset/winter_male/winter_male' + str(file_num) + '.jpg'
  cv2.imwrite(save_file, resized)
  file_num = file_num+1
# Out:
# /content/drive/MyDrive/face/winter/soo/00000000.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000004.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000005.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000003.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000002.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000001.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000009.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000006.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000007.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000011.jpg
# 이미지 사이즈 : (101, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 101
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30300
# /content/drive/MyDrive/face/winter/soo/00000012.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000010.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000013.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000016.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000014.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000017.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000019.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000020.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000023.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000024.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000025.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000026.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000027.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000029.jpg
# 이미지 사이즈 : (101, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 101
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30300
# /content/drive/MyDrive/face/winter/soo/00000028.jpg
# 이미지 사이즈 : (99, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 99
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 29700
# /content/drive/MyDrive/face/winter/soo/00000030.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000031.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000033.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000036.jpg
# 이미지 사이즈 : (99, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 99
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 29700
# /content/drive/MyDrive/face/winter/soo/00000039.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000042.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000041.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000044.jpg
# 이미지 사이즈 : (101, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 101
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30300
# /content/drive/MyDrive/face/winter/soo/00000043.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000047.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000049.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000051.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000052.jpg
# 이미지 사이즈 : (98, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 98
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 29400
# /content/drive/MyDrive/face/winter/soo/00000054.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000055.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000058.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000062.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000063.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000064.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000065.jpg
# 이미지 사이즈 : (99, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 99
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 29700
# /content/drive/MyDrive/face/winter/soo/00000069.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000071.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000074.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000072.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000077.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000076.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000078.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000079.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000080.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000081.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000085.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000084.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000088.jpg
# 이미지 사이즈 : (101, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 101
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30300
# /content/drive/MyDrive/face/winter/soo/00000087.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000091.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000092.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000094.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000095.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
# /content/drive/MyDrive/face/winter/soo/00000097.jpg
# 이미지 사이즈 : (100, 100, 3)
# 이미지 dtype : uint8
# 이미지 Height : 100
# 이미지 Width : 100
# 이미지 전체 픽셀 개수 : 30000
